# %% [markdown]
# ### Instalamos dependencias de NLTK

# %%
import nltk

nltk.download('punkt')

nltk.download('averaged_perceptron_tagger')

nltk.download('maxent_ne_chunker')

nltk.download('words')

from pprint import pprint
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.

# %% [markdown]
# Definimos función

# %%
def get_pos(text):
  '''
  Devuelve las categorías morfológicas (Part-Of-Speech, POS)  de los tokens
  '''
  tokens = nltk.tokenize.word_tokenize(text)
  pos = nltk.tag.pos_tag(tokens)
  return pos

# %%
pprint(get_pos('Google is an American multinational technology company founded in '
 '1998 that specializes in Internet-related services and products.'))
# Out:
# [('Google', 'NNP'),
#  ('is', 'VBZ'),
#  ('an', 'DT'),
#  ('American', 'JJ'),
#  ('multinational', 'NN'),
#  ('technology', 'NN'),
#  ('company', 'NN'),
#  ('founded', 'VBD'),
#  ('in', 'IN'),
#  ('1998', 'CD'),
#  ('that', 'WDT'),
#  ('specializes', 'VBZ'),
#  ('in', 'IN'),
#  ('Internet-related', 'NNP'),
#  ('services', 'NNS'),
#  ('and', 'CC'),
#  ('products', 'NNS'),
#  ('.', '.')]

# %% [markdown]
# Invocamos función de NER `ne_chunck`

# %%
print(nltk.ne_chunk(get_pos('Google is an American multinational technology company' 
                             'founded in 1998 that specializes in Internet-related '
                             'services and products.')))
# Out:
# (S
#   (GPE Google/NNP)
#   is/VBZ
#   an/DT
#   (GPE American/JJ)
#   multinational/JJ
#   technology/NN
#   companyfounded/VBN
#   in/IN
#   1998/CD
#   that/WDT
#   specializes/VBZ
#   in/IN
#   Internet-related/NNP
#   services/NNS
#   and/CC
#   products/NNS
#   ./.)

# %% [markdown]
# Función para análisis sintáctico

# %%
def parse_groups(pos):
  pattern = 'NP: {(<N.+>|<DT>|<JJ>|<CC>)*<N.+>}'
  return nltk.RegexpParser(pattern).parse(pos)

print(parse_groups(get_pos('Google is an American multinational technology company'
        ' founded in 1998 that specializes in Internet-related services and products.')))
# Out:
# (S
#   (NP Google/NNP)
#   is/VBZ
#   (NP an/DT American/JJ multinational/NN technology/NN company/NN)
#   founded/VBD
#   in/IN
#   1998/CD
#   that/WDT
#   specializes/VBZ
#   in/IN
#   (NP Internet-related/NNP services/NNS and/CC products/NNS)
#   ./.)

# %% [markdown]
# Obtiene el etiquetado en notación IOB

# %%
pprint(nltk.chunk.tree2conlltags(parse_groups(get_pos('Google is an American multinational technology '
'company founded in 1998 that specializes in Internet-related services and products.'))))
# Out:
# [('Google', 'NNP', 'B-NP'),
#  ('is', 'VBZ', 'O'),
#  ('an', 'DT', 'B-NP'),
#  ('American', 'JJ', 'I-NP'),
#  ('multinational', 'NN', 'I-NP'),
#  ('technology', 'NN', 'I-NP'),
#  ('company', 'NN', 'I-NP'),
#  ('founded', 'VBD', 'O'),
#  ('in', 'IN', 'O'),
#  ('1998', 'CD', 'O'),
#  ('that', 'WDT', 'O'),
#  ('specializes', 'VBZ', 'O'),
#  ('in', 'IN', 'O'),
#  ('Internet-related', 'NNP', 'B-NP'),
#  ('services', 'NNS', 'I-NP'),
#  ('and', 'CC', 'I-NP'),
#  ('products', 'NNS', 'I-NP'),
#  ('.', '.', 'O')]

# %% [markdown]
# ### Instalamos dependencias de SpaCy

# %%
import spacy
import en_core_web_sm

# Cargar segmentador, analizador y NER en inglés
nlp = en_core_web_sm.load()

# %% [markdown]
# Extracción de entidades de la frase con etiquetado IOB

# %%
doc = nlp('Google LLC is an American multinational technology company founded in 1998'
 ' that specializes in Internet-related services and products.')

pprint([(X, X.ent_iob_, X.ent_type_) for X in doc])
# Out:
# [(Google, 'B', 'ORG'),
#  (LLC, 'I', 'ORG'),
#  (is, 'O', ''),
#  (an, 'O', ''),
#  (American, 'B', 'NORP'),
#  (multinational, 'O', ''),
#  (technology, 'O', ''),
#  (company, 'O', ''),
#  (founded, 'O', ''),
#  (in, 'O', ''),
#  (1998, 'B', 'DATE'),
#  (that, 'O', ''),
#  (specializes, 'O', ''),
#  (in, 'O', ''),
#  (Internet, 'O', ''),
#  (-, 'O', ''),
#  (related, 'O', ''),
#  (services, 'O', ''),
#  (and, 'O', ''),
#  (products, 'O', ''),
#  (., 'O', '')]

# %% [markdown]
# Desplegar de manera visual las entidades reconocidas

# %%
spacy.displacy.render(nlp('Google is an American multinational technology company founded in'
 ' 1998 that specializes in Internet-related services and products.'), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is an
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     American
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  multinational technology company founded in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1998
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  that specializes in Internet-related services and products.</div></span>

# %% [markdown]
# Desplegar de manera visual las dependencias sintácticas de la frase

# %%
spacy.displacy.render(nlp('Google is an American multinational technology company founded in'
 ' 1998 that specializes in Internet-related services and products.'), jupyter=True, style='dep')
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="45e6c702dcdb4f2784e9a2a1ff1c6028-0" class="displacy" width="3200" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Google</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">American</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">multinational</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">technology</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">company</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">founded</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">1998</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">specializes</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">Internet-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">related</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">services</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">products.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-45e6c702dcdb4f2784e9a2a1ff1c6028-0-0" stroke-width="2px" d="M70,439.5 C70,352.0 205.0,352.0 205.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-45e6c702dcdb4f2784e9a2a1ff1c6028-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,441.5 L62,429.5 78,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-45e6c702dcdb4f2784e9a2a1ff1c6028-0-1" stroke-width="2px" d="M420,439.5 C420,89.5 1095.0,89.5 1095.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-45e6c702dcdb4f2784e9a2a1ff1c6028-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,441.5 L412,429.5 428,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-45e6c702dcdb4f2784e9a2a1ff1c6028-0-2" stroke-width="2px" d="M595,439.5 C595,177.0 1090.0,177.0 1090.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-45e6c702dcdb4f2784e9a2a1ff1c6028-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,441.5 L587,429.5 603,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-45e6c702dcdb4f2784e9a2a1ff1c6028-0-3" stroke-width="2px" d="M770,439.5 C770,352.0 905.0,352.0 905.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-45e6c702dcdb4f2784e9a2a1ff1c6028-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,441.5 L762,429.5 778,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-45e6c702dcdb4f2784e9a2a1ff1c6028-0-4" stroke-width="2px" d="M945,439.5 C945,352.0 1080.0,352.0 1080.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-45e6c702dcdb4f2784e9a2a1ff1c6028-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,441.5 L937,429.5 953,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-45e6c702dcdb4f2784e9a2a1ff1c6028-0-5" stroke-width="2px" d="M245,439.5 C245,2.0 1100.0,2.0 1100.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">

# %% [markdown]
# Modelo en español para prueba con frase en este idioma

# %%
# !python -m spacy download es_core_news_sm
# Out:
# Installing collected packages: es-core-news-sm
# Successfully installed es-core-news-sm-2.2.5
# ✔ Download and installation successful
# You can now load the model via spacy.load('es_core_news_sm')

# %%
import es_core_news_sm
nlp = es_core_news_sm.load()

spacy.displacy.render(nlp('Google LLC es una compañía principal subsidiaria de la multinacional'
  ' estadounidense Alphabet Inc., cuya especialización son los productos y servicios relacionados '
  'con Internet, software, dispositivos electrónicos y otras tecnologías.'), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google LLC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  es una compañía principal subsidiaria de la multinacional estadounidense
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alphabet Inc
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# ., cuya especialización son los productos y servicios relacionados con
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Internet
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# , software, dispositivos electrónicos y otras tecnologías.</div></span>

# %%
import spacy
import es_core_news_sm

nlp = es_core_news_sm.load()

textico = '''Tampoco se engañen los unos a los otros. Porque ustedes se despojaron del hombre viejo 
y de sus obras y se revistieron del hombre nuevo, aquel que avanza hacia el conocimiento perfecto, 
renovándose constantemente según la imagen de su Creador. Por eso, ya no hay pagano ni judío, circunciso 
ni incircunciso, bárbaro ni extranjero, esclavo ni hombre libre, sino sólo Cristo, que es todo y está 
en todos. Como elegidos de Dios, sus santos y amados, revístanse de sentimientos de profunda compasión. 
Practiquen la benevolencia, la humildad, la dulzura, la paciencia. Sopórtense los unos a los otros, y 
perdónense mutuamente siempre que alguien tenga motivo de queja contra otro. El Señor los ha perdonado: 
hagan ustedes lo mismo.Sobre todo, revístanse del amor, que es el vínculo de la perfección. Que la paz 
de Cristo reine en sus corazones: esa paz a la que han sido llamados, porque formamos un solo Cuerpo. 
Y vivan en la acción de gracias. Que la Palabra de Cristo resida en ustedes con toda su riqueza. 
Instrúyanse en la verdadera sabiduría, corrigiéndose los unos a los otros. Canten a Dios con gratitud 
y de todo corazón salmos, himnos y cantos inspirados.'''

doc= nlp(textico)

doc.ents
# Out:
# (Porque ustedes,
#  Creador,
#  Por eso,
#  sólo Cristo,
#  Como elegidos de Dios,
#  Practiquen la benevolencia,
#  Sopórtense,
#  El Señor,
#  Que la paz de Cristo reine,
#  Cuerpo.,
#  Que la Palabra de Cristo,
#  Instrúyanse en la verdadera sabiduría,
#  Canten,
#  Dios)

# %%
for ent in doc.ents:
  print(ent.text, '|',ent.label_)
# Out:
# Porque ustedes | MISC
# Creador | MISC
# Por eso | MISC
# sólo Cristo | PER
# Como elegidos de Dios | MISC
# Practiquen la benevolencia | MISC
# Sopórtense | MISC
# El Señor | LOC
# Que la paz de Cristo reine | MISC
# Cuerpo. | MISC
# Que la Palabra de Cristo | MISC
# Instrúyanse en la verdadera sabiduría | MISC
# Canten | PER
# Dios | MISC

# %%
type(doc.ents[0])
# Out:
# spacy.tokens.span.Span

# %%
print(doc.ents[0], doc.ents[0].start, doc.ents[0].end)
# Out:
# Porque ustedes 9 11

# %%
spacy.explain('MISC')
# Out:
# 'Miscellaneous entities, e.g. events, nationalities, products or works of art'

# %%
spacy.explain('NORP')
# Out:
# 'Nationalities or religious or political groups'

# %%
colores = {"MISC": "linear-gradient(90deg, #aa9cfc, #fc9ce7)"}
opciones = {"ents": ["MISC"], "colors": colores}
spacy.displacy.render(doc, jupyter=True, style='ent', options=opciones)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Tampoco se engañen los unos a los otros.
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Porque ustedes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  se despojaron del hombre viejo y de sus obras y se revistieron del hombre nuevo, aquel que avanza hacia el conocimiento perfecto, renovándose constantemente según la imagen de su
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Creador
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# .
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Por eso
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# , ya no hay pagano ni judío, circunciso ni incircunciso, bárbaro ni extranjero, esclavo ni hombre libre, sino sólo Cristo, que es todo y está en todos.
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Como elegidos de Dios
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# , sus santos y amados, revístanse de sentimientos de profunda compasión.
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Practiquen la benevolencia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# , la humildad, la dulzura, la paciencia.
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sopórtense
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  los unos a los otros, y perdónense mutuamente siempre que alguien tenga motivo de queja contra otro. El Señor los ha perdonado: hagan ustedes lo mismo.Sobre todo, revístanse del amor, que es el vínculo de la perfección.
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Que la paz de Cristo reine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  en sus corazones: esa paz a la que han sido llamados, porque formamos un solo
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cuerpo.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  Y vivan en la acción de gracias.
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Que la Palabra de Cristo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  resida en ustedes con toda su riqueza.
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Instrúyanse en la verdadera sabiduría
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# , corrigiéndose los unos a los otros. Canten a
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dios
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  con gratitud y de todo corazón salmos, himnos y cantos inspirados.</div></span>

# %%
spacy.displacy.render(doc.sents, jupyter=True, style='dep')
# Out:
# Using the 'dep' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.
